# %% [markdown]
# <a href="https://colab.research.google.com/github/Nehapriya1423/HTML/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.2 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="gsk_API_KEY",
    model="llama-3.1-8b-instant",
    temperature=0.3
)

# %%
task = "Write a short polite email asking my professor for a deadline extension."

draft = llm.invoke(task).content

print("----- DRAFT EMAIL -----")
print(draft)
# Out:
# ----- DRAFT EMAIL -----
# Subject: Request for Deadline Extension for [Assignment/Project Name]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to respectfully request a deadline extension for the [Assignment/Project Name] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., personal circumstances, academic commitments, or unforeseen challenges], I require some additional time to complete the assignment to the best of my abilities.
#
# I am confident that with a brief extension, I will be able to submit high-quality work that meets your expectations. I would greatly appreciate an extension of [Specific Number of Days] to [New Due Date].
#
# If this is feasible, please let me know and I will make sure to adjust my schedule accordingly. I appreciate your understanding and flexibility in this matter.
#
# Thank you for considering my request.
#
# Sincerely,
# [Your Name]

# %%
decision = input("Type APPROVED to send, or anything else to reject: ")

if decision.strip().upper() == "APPROVED":
    print("✅ Email sent!")
else:
    print("❌ Not sent. The draft was rejected.")
# Out:
# Type APPROVED to send, or anything else to reject: APPROVED
# ✅ Email sent!
